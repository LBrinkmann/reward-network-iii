# %% [markdown]
# ## Pilot 3B

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_theme(style="darkgrid")

from dotenv import load_dotenv
import os
import glob
import json

# %%
# directory management
pilot_name = "rn-iii-pilot-3"
to_save_plots = True
data_path = f"../../data/for_plots/{pilot_name}"

figures_path = f"../figures/{pilot_name}"
if not os.path.exists(figures_path):
    os.makedirs(figures_path)

scores_df = pd.read_csv(os.path.join(data_path,"scores.csv"),index_col=0)
trials_time = pd.read_csv(os.path.join(data_path,"trials_time.csv"))
sessions_time = pd.read_csv(os.path.join(data_path,"sessions_time.csv"))
post_survey_df = pd.read_csv(os.path.join(data_path,"post_survey_df.csv"))

# %% [markdown]
# ## post survey plots

# %%
variables = ['task_explanation', 'difficulty_rating', 'time_limit_sufficient', 'arrows_color']
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, len(variables), sharey=True, figsize=(18, 6))

sns.countplot(data=post_survey_df, x="task_explanation", hue="expName", ax=ax1)
ax1.set_xlabel('task explanation \n (higher is clearer)')
sns.countplot(data=post_survey_df, x="difficulty_rating", hue="expName", ax=ax2)
ax2.set_xlabel('difficulty rating \n (higher is more difficult)')
sns.countplot(data=post_survey_df, x="time_limit_sufficient", hue="expName", ax=ax3)
ax3.set_xlabel('time limit sufficient \n (higher is too much time)')
sns.countplot(data=post_survey_df, x="arrows_color", hue="expName", ax=ax4)
ax4.set_xlabel('Color of arrows \n (higher is hard to distinguish)')

if to_save_plots:
    f.savefig(os.path.join(figures_path, 'post_survey.pdf'), format='pdf', dpi=300)
    f.savefig(os.path.join(figures_path, 'post_survey.png'), format='png', dpi=300)

# %% [markdown]
# ## Scores plots
# ### preprocessing

# %%
#scores_df['trialIdx'] = scores_df['trialIdx'].astype('int')
scores_df.replace({"isAI": {True: 'AI', False: 'Human'}}, inplace=True)
scores_df.groupby(by=["expName","trialType","isAI"]).size()
# Out:
# expName          trialType      isAI
# rn-iii-pilot-3B  demonstration  AI       20
#                                 Human    20
#                  individual     AI       40
#                                 Human    60
#                  try_yourself   AI       10
#                                 Human    80
# dtype: int64

# %% [markdown]
# ## decode the before and after individual and try_yourself trials

# %%
scores_df
# Out:
#                     sessionId   isAI          expName  generation  trialIdx  \
# 0    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       NaN
# 1    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       0.0
# 2    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       1.0
# 3    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       2.0
# 4    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       3.0
# ..                        ...    ...              ...         ...       ...
# 225  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      25.0
# 226  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      26.0
# 227  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      27.0
# 228  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      29.0
# 229  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      30.0
#
#          trialType                         networkId   score  maxLevelReached  \
# 0     try_yourself                               NaN     NaN              NaN
# 1       individual  ee03606912fff2d5496ca438ddf0e182  1050.0              4.0
# 2       individual  b06e63e23be6e795171cc39de5f68b04  1050.0              4.0
# 3       individual  cb226a27079683c5a81e7c73450fd1d7   850.0              4.0
# 4       individual  bbd3fb74933edbeb8aee7fb3ead010ec  1250.0              4.0
# ..             ...                               ...     ...              ...
# 225     individual  a2c663a5e2c6b59d546691602456bfce   100.0              2.0
# 226     individual  35f070abfb64c2499229d1ee32cf54b6  1050.0              1.0
# 227     individual  8873dfa1b3059e8c7bbb2a75f76b3b83   350.0              1.0
# 228  demonstration  59bc73ae47a896adda8a3eeec20e03fb  1000.0              2.0
# 229  demonstration  04fc6cbee3837127477c7577f39b61d5   350.0              2.0
#
#      myopic_score  ai_score
# 0             NaN       NaN
# 1           600.0    1050.0
# 2          1200.0    1050.0
# 3           800.0     850.0
# 4           800.0    1250.0
# ..            ...       ...
# 225           0.0    1250.0
# 226        1100.0    1450.0
# 227         350.0    1250.0
# 228         650.0     850.0
# 229         300.0    1450.0
#
# [230 rows x 11 columns]

# %%
scores_df_ai = scores_df[scores_df['isAI']=='AI']
scores_df_human = scores_df[scores_df['isAI']=='Human']

scores_df_human.loc[scores_df_human['trialIdx'].isin([10,13,17,20]), 'trialType'] = 'try_yourself_before'
scores_df_human.loc[scores_df_human['trialIdx'].isin([12,15,19,22]), 'trialType'] = 'try_yourself_after'
scores_df_human.loc[scores_df_human['trialIdx'].isin([4,5]), 'trialType'] = 'individual_before'
scores_df_human.loc[scores_df_human['trialIdx'].isin([24,25,26,27]), 'trialType'] = 'individual_after'

scores_df = pd.concat([scores_df_ai, scores_df_human])

# %%
scores_df.groupby(by=["expName","trialType","isAI"]).size()
# Out:
# expName          trialType            isAI
# rn-iii-pilot-3B  demonstration        AI       20
#                                       Human    20
#                  individual           AI       40
#                  individual_after     Human    40
#                  individual_before    Human    20
#                  try_yourself         AI       10
#                  try_yourself_after   Human    40
#                  try_yourself_before  Human    40
# dtype: int64

# %%
# create plot hue
scores_df['plot_hue'] = scores_df['isAI'].astype(str) + ', ' + scores_df['trialType'].astype(str)
scores_df
# Out:
#                     sessionId   isAI          expName  generation  trialIdx  \
# 0    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       NaN
# 1    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       0.0
# 2    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       1.0
# 3    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       2.0
# 4    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       3.0
# ..                        ...    ...              ...         ...       ...
# 225  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      25.0
# 226  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      26.0
# 227  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      27.0
# 228  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      29.0
# 229  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      30.0
#
#             trialType                         networkId   score  \
# 0        try_yourself                               NaN     NaN
# 1          individual  ee03606912fff2d5496ca438ddf0e182  1050.0
# 2          individual  b06e63e23be6e795171cc39de5f68b04  1050.0
# 3          individual  cb226a27079683c5a81e7c73450fd1d7   850.0
# 4          individual  bbd3fb74933edbeb8aee7fb3ead010ec  1250.0
# ..                ...                               ...     ...
# 225  individual_after  a2c663a5e2c6b59d546691602456bfce   100.0
# 226  individual_after  35f070abfb64c2499229d1ee32cf54b6  1050.0
# 227  individual_after  8873dfa1b3059e8c7bbb2a75f76b3b83   350.0
# 228     demonstration  59bc73ae47a896adda8a3eeec20e03fb  1000.0
# 229     demonstration  04fc6cbee3837127477c7577f39b61d5   350.0
#
#      maxLevelReached  myopic_score  ai_score                 plot_hue
# 0                NaN           NaN       NaN         AI, try_yourself
# 1                4.0         600.0    1050.0           AI, individual
# 2                4.0        1200.0    1050.0           AI, individual
# 3                4.0         800.0     850.0           AI, individual
# 4                4.0         800.0    1250.0           AI, individual
# ..               ...           ...       ...                      ...
# 225              2.0           0.0    1250.0  Human, individual_after
# 226              1.0        1100.0    1450.0  Human, individual_after
# 227              1.0         350.0    1250.0  Human, individual_after
# 228              2.0         650.0     850.0     Human, demonstration
# 229              2.0         300.0    1450.0     Human, demonstration
#
# [230 rows x 12 columns]

# %%
#box, ax = plt.subplots(figsize=(6.5, 6.5))
#sns.boxplot(scores_df, x="plot_hue", y="score", ax=ax, width=6)

fig1 = sns.catplot(data=scores_df, x="score", y="plot_hue", hue='isAI', kind="box", height=5, aspect=3)
fig1.fig.subplots_adjust(top=0.9)
fig1.fig.suptitle('RN-III Pilot 3B')

if to_save_plots:
    fig1.savefig(os.path.join(figures_path, 'Reward_boxplot_trial_type.pdf'), format='pdf', dpi=300)
    fig1.savefig(os.path.join(figures_path, 'Reward_boxplot_trial_type.png'), format='png', dpi=300)

# %%
# average score per participant
scores_df.groupby(by=["sessionId",'isAI','trialType'])['score'].mean().to_frame('avg_score_participant').reset_index()
# Out:
#                    sessionId   isAI            trialType  \
# 0   6422d978aff8868105633828     AI        demonstration
# 1   6422d978aff8868105633828     AI           individual
# 2   6422d978aff8868105633828     AI         try_yourself
# 3   6422d978aff8868105633829     AI        demonstration
# 4   6422d978aff8868105633829     AI           individual
# ..                       ...    ...                  ...
# 75  6422d978aff886810563383c  Human        demonstration
# 76  6422d978aff886810563383c  Human     individual_after
# 77  6422d978aff886810563383c  Human    individual_before
# 78  6422d978aff886810563383c  Human   try_yourself_after
# 79  6422d978aff886810563383c  Human  try_yourself_before
#
#     avg_score_participant
# 0                  1150.0
# 1                  1050.0
# 2                     NaN
# 3                  1350.0
# 4                  1250.0
# ..                    ...
# 75                  675.0
# 76                  725.0
# 77                 -525.0
# 78                  837.5
# 79                 1137.5
#
# [80 rows x 4 columns]

# %% [markdown]
# ## Find out which advisors were loss AI, and which were myopic AI

# %%
moves = pd.read_csv(os.path.join(f"../../data/final/rn-iii-pilot-3B/moves.csv"),sep=',', index_col=0)
moves
# Out:
#                      sessionId  trialID                         networkId  \
# 0     6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 1     6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 2     6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 3     6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 4     6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# ...                        ...      ...                               ...
# 1755  6422d978aff886810563383c       30  04fc6cbee3837127477c7577f39b61d5
# 1756  6422d978aff886810563383c       30  04fc6cbee3837127477c7577f39b61d5
# 1757  6422d978aff886810563383c       30  04fc6cbee3837127477c7577f39b61d5
# 1758  6422d978aff886810563383c       30  04fc6cbee3837127477c7577f39b61d5
# 1759  6422d978aff886810563383c       30  04fc6cbee3837127477c7577f39b61d5
#
#       sourceLevel  targetLevel  reward  step  isMissing  matchesMyopic  \
# 0               0            1     -50     1      False          False
# 1               1            2     -50     2      False          False
# 2               2            3     -50     3      False          False
# 3               3            4     200     4      False          False
# 4               4            3     400     5      False          False
# ...           ...          ...     ...   ...        ...            ...
# 1755            0            0     100     4      False          False
# 1756            0            1     -50     5      False          False
# 1757            1            2     -50     6      False          False
# 1758            2            0     400     7      False          False
# 1759            0            0       0     8      False           True
#
#       matchesAI
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ...         ...
# 1755      False
# 1756      False
# 1757      False
# 1758      False
# 1759      False
#
# [1760 rows x 10 columns]

# %%
ai_session_ids = list(scores_df[scores_df['isAI']=='AI']['sessionId'].unique())
moves_ai = moves[moves['sessionId'].isin(ai_session_ids)]
moves_ai
# Out:
#                     sessionId  trialID                         networkId  \
# 0    6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 1    6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 2    6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 3    6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# 4    6422d978aff8868105633828        0  ee03606912fff2d5496ca438ddf0e182
# ..                        ...      ...                               ...
# 475  6422d978aff8868105633831        5  e8734b5b66bca9a8369582876f59eafe
# 476  6422d978aff8868105633831        5  e8734b5b66bca9a8369582876f59eafe
# 477  6422d978aff8868105633831        5  e8734b5b66bca9a8369582876f59eafe
# 478  6422d978aff8868105633831        5  e8734b5b66bca9a8369582876f59eafe
# 479  6422d978aff8868105633831        5  e8734b5b66bca9a8369582876f59eafe
#
#      sourceLevel  targetLevel  reward  step  isMissing  matchesMyopic  \
# 0              0            1     -50     1      False          False
# 1              1            2     -50     2      False          False
# 2              2            3     -50     3      False          False
# 3              3            4     200     4      False          False
# 4              4            3     400     5      False          False
# ..           ...          ...     ...   ...        ...            ...
# 475            0            0     100     4      False           True
# 476            0            0     100     5      False           True
# 477            0            0     100     6      False           True
# 478            0            0     100     7      False           True
# 479            0            0     100     8      False           True
#
#      matchesAI
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ..         ...
# 475      False
# 476      False
# 477      False
# 478      False
# 479      False
#
# [480 rows x 10 columns]

# %%
moves_matches = moves_ai.groupby(by=['sessionId']).agg(n_myopic_matches=('matchesMyopic','sum'),
                                       n_ai_matches=('matchesAI','sum')).reset_index()

loss_ai = list(moves_matches[moves_matches['n_myopic_matches']<=1]['sessionId'])
myopic_ai = list(moves_matches[moves_matches['n_myopic_matches']>1]['sessionId'])

# %%
myopic_ai
# Out:
# ['6422d978aff886810563382b',
#  '6422d978aff886810563382c',
#  '6422d978aff886810563382d',
#  '6422d978aff886810563382e',
#  '6422d978aff886810563382f',
#  '6422d978aff8868105633830',
#  '6422d978aff8868105633831']

# %%
scores_df
# Out:
#                     sessionId   isAI          expName  generation  trialIdx  \
# 0    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       NaN
# 1    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       0.0
# 2    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       1.0
# 3    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       2.0
# 4    6422d978aff8868105633828     AI  rn-iii-pilot-3B           0       3.0
# ..                        ...    ...              ...         ...       ...
# 225  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      25.0
# 226  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      26.0
# 227  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      27.0
# 228  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      29.0
# 229  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      30.0
#
#             trialType                         networkId   score  \
# 0        try_yourself                               NaN     NaN
# 1          individual  ee03606912fff2d5496ca438ddf0e182  1050.0
# 2          individual  b06e63e23be6e795171cc39de5f68b04  1050.0
# 3          individual  cb226a27079683c5a81e7c73450fd1d7   850.0
# 4          individual  bbd3fb74933edbeb8aee7fb3ead010ec  1250.0
# ..                ...                               ...     ...
# 225  individual_after  a2c663a5e2c6b59d546691602456bfce   100.0
# 226  individual_after  35f070abfb64c2499229d1ee32cf54b6  1050.0
# 227  individual_after  8873dfa1b3059e8c7bbb2a75f76b3b83   350.0
# 228     demonstration  59bc73ae47a896adda8a3eeec20e03fb  1000.0
# 229     demonstration  04fc6cbee3837127477c7577f39b61d5   350.0
#
#      maxLevelReached  myopic_score  ai_score                 plot_hue
# 0                NaN           NaN       NaN         AI, try_yourself
# 1                4.0         600.0    1050.0           AI, individual
# 2                4.0        1200.0    1050.0           AI, individual
# 3                4.0         800.0     850.0           AI, individual
# 4                4.0         800.0    1250.0           AI, individual
# ..               ...           ...       ...                      ...
# 225              2.0           0.0    1250.0  Human, individual_after
# 226              1.0        1100.0    1450.0  Human, individual_after
# 227              1.0         350.0    1250.0  Human, individual_after
# 228              2.0         650.0     850.0     Human, demonstration
# 229              2.0         300.0    1450.0     Human, demonstration
#
# [230 rows x 12 columns]

# %%
trial = pd.read_csv(os.path.join(f"../../data/final/rn-iii-pilot-3B/trial.csv"),sep=',')
trial
# Out:
#      Unnamed: 0                 sessionId  generation         trialType  \
# 0             0  6422d978aff8868105633828           0        individual
# 1             1  6422d978aff8868105633828           0        individual
# 2             2  6422d978aff8868105633828           0        individual
# 3             3  6422d978aff8868105633828           0        individual
# 4             4  6422d978aff8868105633828           0     demonstration
# ..          ...                       ...         ...               ...
# 405         405  6422d978aff886810563383c           1     demonstration
# 406         406  6422d978aff886810563383c           1     demonstration
# 407         407  6422d978aff886810563383c           1  written_strategy
# 408         408  6422d978aff886810563383c           1       post_survey
# 409         409  6422d978aff886810563383c           1        debriefing
#
#      trialIdx parentSessionId parentSession_isAI
# 0           0             NaN                NaN
# 1           1             NaN                NaN
# 2           2             NaN                NaN
# 3           3             NaN                NaN
# 4           4             NaN                NaN
# ..        ...             ...                ...
# 405        29             NaN                NaN
# 406        30             NaN                NaN
# 407        31             NaN                NaN
# 408        32             NaN                NaN
# 409        33             NaN                NaN
#
# [410 rows x 7 columns]

# %%
learned_from_myopic_ai = list(trial[trial['parentSessionId'].isin(myopic_ai)]['sessionId'].unique())
learned_from_loss_ai = list(trial[trial['parentSessionId'].isin(loss_ai)]['sessionId'].unique())

# %%
learned_from_myopic_ai
# Out:
# ['6422d978aff8868105633833',
#  '6422d978aff8868105633834',
#  '6422d978aff8868105633837',
#  '6422d978aff886810563383b',
#  '6422d978aff886810563383c']

# %%
learned_from_loss_ai
# Out:
# ['6422d978aff8868105633832',
#  '6422d978aff8868105633833',
#  '6422d978aff8868105633834',
#  '6422d978aff8868105633835',
#  '6422d978aff8868105633836',
#  '6422d978aff8868105633837',
#  '6422d978aff8868105633838',
#  '6422d978aff886810563383a',
#  '6422d978aff886810563383c']

# %% [markdown]
# ## performance across trial plots

# %%
# create plot hue specifically for human - trial type combo
fig = sns.relplot(data=scores_df[scores_df['isAI']=='Human'],
                      x="trialIdx",
                      y="score",
                      hue='plot_hue',
                      col="sessionId",
                      col_wrap=2,
                      kind="line",
                      errorbar='ci',
                      facet_kws=dict(sharey=True,sharex=False),
                      #palette={'individual, Human':'green', 'demonstration, Human':'#6bdb9c'},
                      height=7,
                      aspect=2,
                      legend='full')
fig.set(xlabel="Trial number", ylabel="Score")
fig.fig.suptitle("Pilot 3B")

if to_save_plots:
    fig.savefig(os.path.join(figures_path, 'Score_over_trialIdx_session.pdf'), format='pdf', dpi=300)
    fig.savefig(os.path.join(figures_path, 'Score_over_trialIdx_session.png'), format='png', dpi=300)

# %% [markdown]
# ## check for number of steps in trials

# %%
human_session_ids = list(scores_df[scores_df['isAI']=='Human']['sessionId'].unique())
moves_human = moves[moves['sessionId'].isin(human_session_ids)]
missings = moves_human.groupby(by=['sessionId','trialID']).agg(n_missings=('isMissing','sum')).reset_index()

# %%
missings
# Out:
#                     sessionId  trialID  n_missings
# 0    6422d978aff8868105633832        4           0
# 1    6422d978aff8868105633832        5           0
# 2    6422d978aff8868105633832       10           0
# 3    6422d978aff8868105633832       12           0
# 4    6422d978aff8868105633832       13           0
# ..                        ...      ...         ...
# 155  6422d978aff886810563383c       25           2
# 156  6422d978aff886810563383c       26           0
# 157  6422d978aff886810563383c       27           0
# 158  6422d978aff886810563383c       29           0
# 159  6422d978aff886810563383c       30           0
#
# [160 rows x 3 columns]

# %%
print(f"{len(missings[missings['n_missings']>0])} out of {len(missings)} trials ({len(missings[missings['n_missings']>0]) / len(missings) *100} %) have missing steps")
# Out:
# 17 out of 160 trials (10.625 %) have missing steps

# %%
missings[missings['n_missings']>0]['n_missings'].value_counts(normalize=True)
# Out:
# 1    0.352941
# 5    0.176471
# 4    0.176471
# 3    0.117647
# 7    0.058824
# 8    0.058824
# 2    0.058824
# Name: n_missings, dtype: float64

# %%
print(f"{len(missings[missings['n_missings']>1])} out of {len(missings)} trials ({len(missings[missings['n_missings']>0]) / len(missings) *100} %) have missing steps")
# Out:
# 11 out of 160 trials (10.625 %) have missing steps

# %%
true_missings = missings[missings['n_missings']>0]
true_missings['trialType']='demonstration'
true_missings.loc[true_missings['trialID'].isin([4,5]),'trialType'] = 'individual_before'
true_missings.loc[true_missings['trialID'].between(10,22),'trialType'] = 'try_yourself_before'
true_missings.loc[true_missings['trialID'].isin([25]),'trialType'] = 'individual_after'
true_missings['trialType'].value_counts(normalize=True)
# Out:
# /var/folders/bf/1wzkxhv923145cbh3xbz51kh0000gr/T/ipykernel_1949/2302601842.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   true_missings['trialType']='demonstration'
# individual_before      0.470588
# try_yourself_before    0.235294
# demonstration          0.235294
# individual_after       0.058824
# Name: trialType, dtype: float64

# %%
missings[missings['n_missings']>0]['trialID'].value_counts(normalize=True)
# Out:
# 4     0.352941
# 30    0.117647
# 13    0.117647
# 29    0.117647
# 5     0.117647
# 17    0.058824
# 10    0.058824
# 25    0.058824
# Name: trialID, dtype: float64

# %% [markdown]
# ## level reached plots

# %%
g= sns.catplot(data=scores_df[scores_df['isAI']=='Human'],x="maxLevelReached",
               kind='count',hue='plot_hue',col="plot_hue", col_wrap=2)

if to_save_plots:
    g.savefig(os.path.join(figures_path, 'maxLevel_dist_trial_type.pdf'), format='pdf', dpi=300)
    g.savefig(os.path.join(figures_path, 'maxLevel_dist_trial_type.png'), format='png', dpi=300)

# %% [markdown]
# ## focus on individual trials

# %%
df_individual = scores_df[scores_df['plot_hue'].isin(['Human, individual_before','Human, individual_after'])]
df_try_yourself = scores_df[scores_df['plot_hue'].isin(['Human, try_yourself_before','Human, try_yourself_after'])]
df_individual
# Out:
#                     sessionId   isAI          expName  generation  trialIdx  \
# 78   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1       4.0
# 79   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1       5.0
# 80   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      24.0
# 81   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      25.0
# 82   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      26.0
# 83   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      27.0
# 94   6422d978aff8868105633833  Human  rn-iii-pilot-3B           1       4.0
# 95   6422d978aff8868105633833  Human  rn-iii-pilot-3B           1       5.0
# 96   6422d978aff8868105633833  Human  rn-iii-pilot-3B           1      24.0
# 97   6422d978aff8868105633833  Human  rn-iii-pilot-3B           1      25.0
# 98   6422d978aff8868105633833  Human  rn-iii-pilot-3B           1      26.0
# 99   6422d978aff8868105633833  Human  rn-iii-pilot-3B           1      27.0
# 110  6422d978aff8868105633834  Human  rn-iii-pilot-3B           1       4.0
# 111  6422d978aff8868105633834  Human  rn-iii-pilot-3B           1       5.0
# 112  6422d978aff8868105633834  Human  rn-iii-pilot-3B           1      24.0
# 113  6422d978aff8868105633834  Human  rn-iii-pilot-3B           1      25.0
# 114  6422d978aff8868105633834  Human  rn-iii-pilot-3B           1      26.0
# 115  6422d978aff8868105633834  Human  rn-iii-pilot-3B           1      27.0
# 126  6422d978aff8868105633835  Human  rn-iii-pilot-3B           1       4.0
# 127  6422d978aff8868105633835  Human  rn-iii-pilot-3B           1       5.0
# 128  6422d978aff8868105633835  Human  rn-iii-pilot-3B           1      24.0
# 129  6422d978aff8868105633835  Human  rn-iii-pilot-3B           1      25.0
# 130  6422d978aff8868105633835  Human  rn-iii-pilot-3B           1      26.0
# 131  6422d978aff8868105633835  Human  rn-iii-pilot-3B           1      27.0
# 142  6422d978aff8868105633836  Human  rn-iii-pilot-3B           1       4.0
# 143  6422d978aff8868105633836  Human  rn-iii-pilot-3B           1       5.0
# 144  6422d978aff8868105633836  Human  rn-iii-pilot-3B           1      24.0
# 145  6422d978aff8868105633836  Human  rn-iii-pilot-3B           1      25.0
# 146  6422d978aff8868105633836  Human  rn-iii-pilot-3B           1      26.0
# 147  6422d978aff8868105633836  Human  rn-iii-pilot-3B           1      27.0
# 158  6422d978aff8868105633837  Human  rn-iii-pilot-3B           1       4.0
# 159  6422d978aff8868105633837  Human  rn-iii-pilot-3B           1       5.0
# 160  6422d978aff8868105633837  Human  rn-iii-pilot-3B           1      24.0
# 161  6422d978aff8868105633837  Human  rn-iii-pilot-3B           1      25.0
# 162  6422d978aff8868105633837  Human  rn-iii-pilot-3B           1      26.0
# 163  6422d978aff8868105633837  Human  rn-iii-pilot-3B           1      27.0
# 174  6422d978aff8868105633838  Human  rn-iii-pilot-3B           1       4.0
# 175  6422d978aff8868105633838  Human  rn-iii-pilot-3B           1       5.0
# 176  6422d978aff8868105633838  Human  rn-iii-pilot-3B           1      24.0
# 177  6422d978aff8868105633838  Human  rn-iii-pilot-3B           1      25.0
# 178  6422d978aff8868105633838  Human  rn-iii-pilot-3B           1      26.0
# 179  6422d978aff8868105633838  Human  rn-iii-pilot-3B           1      27.0
# 190  6422d978aff886810563383a  Human  rn-iii-pilot-3B           1       4.0
# 191  6422d978aff886810563383a  Human  rn-iii-pilot-3B           1       5.0
# 192  6422d978aff886810563383a  Human  rn-iii-pilot-3B           1      24.0
# 193  6422d978aff886810563383a  Human  rn-iii-pilot-3B           1      25.0
# 194  6422d978aff886810563383a  Human  rn-iii-pilot-3B           1      26.0
# 195  6422d978aff886810563383a  Human  rn-iii-pilot-3B           1      27.0
# 206  6422d978aff886810563383b  Human  rn-iii-pilot-3B           1       4.0
# 207  6422d978aff886810563383b  Human  rn-iii-pilot-3B           1       5.0
# 208  6422d978aff886810563383b  Human  rn-iii-pilot-3B           1      24.0
# 209  6422d978aff886810563383b  Human  rn-iii-pilot-3B           1      25.0
# 210  6422d978aff886810563383b  Human  rn-iii-pilot-3B           1      26.0
# 211  6422d978aff886810563383b  Human  rn-iii-pilot-3B           1      27.0
# 222  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1       4.0
# 223  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1       5.0
# 224  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      24.0
# 225  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      25.0
# 226  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      26.0
# 227  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      27.0
#
#              trialType                         networkId   score  \
# 78   individual_before  e9073951acef262498eac37b38155caf   900.0
# 79   individual_before  282a6cc7486e263d2b0fee9e3f1972f7   900.0
# 80    individual_after  d34c336c4eb89dcdbf7822e604104c8d   650.0
# 81    individual_after  effdef11328d73c3c5fb806e1f13adc1   950.0
# 82    individual_after  0f145ca3e4e5228d4e3449f685bb10b8   600.0
# 83    individual_after  0bddb988344c63b517199423b95804e4  1500.0
# 94   individual_before  5d7c38f6314a4ad3ae28ea51f832d6b5  -350.0
# 95   individual_before  ef6faa2a7b3212e04fdf1a319b796812   600.0
# 96    individual_after  23eec9f49d5651260877a2b0f926979a  1200.0
# 97    individual_after  268b96a55e3092c64316ab7dcb993406   700.0
# 98    individual_after  fbb1ccf568906e9b36f2f0dce5fe5d9f   700.0
# 99    individual_after  91cdbb8e2f9597586478fa053981cb26  1200.0
# 110  individual_before  dd33e76ce36532d66d6ae40164cc2235   750.0
# 111  individual_before  03d27900534c8d5cf45d608815e61639   950.0
# 112   individual_after  dc8cf713b9c5aed18e6e65c78884ece4  1250.0
# 113   individual_after  d4329f9d09e26255b7558ae1bb3500f4   600.0
# 114   individual_after  d0a1983cf5a191aeae23939165dc3c67   800.0
# 115   individual_after  ba32ac7f7714b924c1e4b44004b4c273   500.0
# 126  individual_before  c83906ad4f596c0a823e4de788c2404d   550.0
# 127  individual_before  0e64dec233622fb2b0a7c82bf7b9bb1f  1000.0
# 128   individual_after  2982eadd7289c898bd3abc510c94330d  1450.0
# 129   individual_after  5ea5e6aef62c6857db6990a8955ebe62  1050.0
# 130   individual_after  7844225719e3ebf6a2ddd97c7674256c  1650.0
# 131   individual_after  b25cbf1a6c9fcc2202610a2c6d0a9677   550.0
# 142  individual_before  7f75a5d863126faaf87cfbb1950f37df  1000.0
# 143  individual_before  396a769fc7b9a1cd199fe20a1dd60cc3  -150.0
# 144   individual_after  f5d9fc0b1cf995ecf9962f126fe3b156   850.0
# 145   individual_after  a432d08d2e2a0d22a4efcc5762f09651  1050.0
# 146   individual_after  6ed5182068180c598b98642322910ff0   850.0
# 147   individual_after  b61897a0fbb034f08ec2b64bb6fe69ef   800.0
# 158  individual_before  9bea7eb62b55a08ef612a67888b55126   900.0
# 159  individual_before  e7381de84427aa5f84385a1a70ff8e2d   250.0
# 160   individual_after  1fc8bdb24b08c5259812ee6af2e38258   700.0
# 161   individual_after  2a156e09cfb8d47f31059e2640a4b467   700.0
# 162   individual_after  98ce296aabab9bf7a1731a5cebf0ebd3   200.0
# 163   individual_after  fa7a8ccf19ebcb054284ef969f3140e3   850.0
# 174  individual_before  6a4c27fa58ec558d13439f95d42cabd5   100.0
# 175  individual_before  515eea944e8313daf1472f46c1008452  1300.0
# 176   individual_after  24fbb1a696f71d6e0d1b5108480f9264   250.0
# 177   individual_after  7c0face8fe529e50525e26b60db8f436  1200.0
# 178   individual_after  f4c9313397b905f5ade1ab3aadf50f4b  1000.0
# 179   individual_after  467ab64f941ace4e6ed1b7cf94dc3c9c   400.0
# 190  individual_before  4ab7472b6a26591dfe51bf3966bed8a0   300.0
# 191  individual_before  cb5d7e8650f27a14d59f573111500b5b   600.0
# 192   individual_after  4202d83950f191cf8bd3cea9d80ccf3a   550.0
# 193   individual_after  a80bb106753fd224816dba14d2a8d2de  1250.0
# 194   individual_after  328c686594ae3e8ddfeb86aa3ff37f3b   850.0
# 195   individual_after  5debc29265b15de1070aaf71d07462b3  1250.0
# 206  individual_before  4e749f7b49d3c2e88b8f5c5c4684d2d9  -750.0
# 207  individual_before  7fff569c6acf1238b50d95d7f48ca82c   600.0
# 208   individual_after  9d7903f67b2fe171f5843d7ad3c9fce6  1300.0
# 209   individual_after  51ecc335738554e1e1ffafa610ffeaca  1600.0
# 210   individual_after  4a0f2799f32f05bd886ba8824e85c9ca  1200.0
# 211   individual_after  886ed8fb1ee7c16b3d884dd1cffc464b  1100.0
# 222  individual_before  70a8b9fb604c3854ad6558966854ec24  -800.0
# 223  individual_before  aee075bb502f66a59de3d50d93a74501  -250.0
# 224   individual_after  be0a0a73fe40cff1b154ba8e05e59111  1400.0
# 225   individual_after  a2c663a5e2c6b59d546691602456bfce   100.0
# 226   individual_after  35f070abfb64c2499229d1ee32cf54b6  1050.0
# 227   individual_after  8873dfa1b3059e8c7bbb2a75f76b3b83   350.0
#
#      maxLevelReached  myopic_score  ai_score                  plot_hue
# 78               2.0        1000.0    1150.0  Human, individual_before
# 79               1.0         400.0    1050.0  Human, individual_before
# 80               1.0         800.0    1450.0   Human, individual_after
# 81               4.0        1200.0    1250.0   Human, individual_after
# 82               1.0         400.0    1250.0   Human, individual_after
# 83               0.0        1500.0    1650.0   Human, individual_after
# 94               1.0         900.0    1250.0  Human, individual_before
# 95               4.0         650.0    1250.0  Human, individual_before
# 96               0.0        1200.0    1250.0   Human, individual_after
# 97               1.0         600.0    1050.0   Human, individual_after
# 98               4.0         500.0    1450.0   Human, individual_after
# 99               0.0        1000.0    1250.0   Human, individual_after
# 110              2.0        1300.0    1250.0  Human, individual_before
# 111              4.0        1200.0    1250.0  Human, individual_before
# 112              4.0         800.0    1250.0   Human, individual_after
# 113              4.0         400.0    1450.0   Human, individual_after
# 114              2.0         300.0    1050.0   Human, individual_after
# 115              2.0        1200.0    1450.0   Human, individual_after
# 126              1.0        1100.0    1650.0  Human, individual_before
# 127              2.0        1100.0    1250.0  Human, individual_before
# 128              4.0         250.0    1250.0   Human, individual_after
# 129              4.0         400.0    1250.0   Human, individual_after
# 130              4.0         800.0    1650.0   Human, individual_after
# 131              4.0         800.0     850.0   Human, individual_after
# 142              2.0         800.0    1250.0  Human, individual_before
# 143              3.0        1000.0    1250.0  Human, individual_before
# 144              4.0         600.0    1050.0   Human, individual_after
# 145              4.0        1000.0    1050.0   Human, individual_after
# 146              4.0         300.0    1650.0   Human, individual_after
# 147              2.0        1600.0    1050.0   Human, individual_after
# 158              1.0         800.0    1050.0  Human, individual_before
# 159              1.0         400.0    1050.0  Human, individual_before
# 160              2.0         450.0    1250.0   Human, individual_after
# 161              2.0         800.0    1450.0   Human, individual_after
# 162              2.0           0.0    1450.0   Human, individual_after
# 163              1.0        1200.0    1250.0   Human, individual_after
# 174              2.0         700.0    1450.0  Human, individual_before
# 175              2.0        1400.0    1650.0  Human, individual_before
# 176              2.0         800.0    1250.0   Human, individual_after
# 177              0.0        1200.0    1250.0   Human, individual_after
# 178              2.0         600.0    1450.0   Human, individual_after
# 179              2.0         400.0    1450.0   Human, individual_after
# 190              3.0         100.0    1450.0  Human, individual_before
# 191              2.0         900.0     850.0  Human, individual_before
# 192              2.0         900.0    1250.0   Human, individual_after
# 193              4.0         550.0    1050.0   Human, individual_after
# 194              1.0           0.0    1050.0   Human, individual_after
# 195              4.0         800.0    1250.0   Human, individual_after
# 206              1.0         300.0    1050.0  Human, individual_before
# 207              1.0        1600.0    1450.0  Human, individual_before
# 208              0.0        1300.0    1450.0   Human, individual_after
# 209              0.0        1600.0    1450.0   Human, individual_after
# 210              0.0        1200.0    1050.0   Human, individual_after
# 211              0.0        1100.0    1050.0   Human, individual_after
# 222              0.0         200.0    1250.0  Human, individual_before
# 223              1.0         550.0    1650.0  Human, individual_before
# 224              0.0        1400.0    1650.0   Human, individual_after
# 225              2.0           0.0    1250.0   Human, individual_after
# 226              1.0        1100.0    1450.0   Human, individual_after
# 227              1.0         350.0    1250.0   Human, individual_after

# %%
df_individual.loc[df_individual['trialIdx']==4,'trialIdx']=1
df_individual.loc[df_individual['trialIdx']==5,'trialIdx']=2
df_individual.loc[df_individual['trialIdx']==24,'trialIdx']=3
df_individual.loc[df_individual['trialIdx']==25,'trialIdx']=4
df_individual.loc[df_individual['trialIdx']==26,'trialIdx']=5
df_individual.loc[df_individual['trialIdx']==27,'trialIdx']=6

# individual performance over trial idx (score)
prova = sns.relplot(data=df_individual, x="trialIdx", y="score",
                    hue='plot_hue', kind="line", errorbar='sd',
                    facet_kws=dict(sharey=True,sharex=False))
# add label to the axis and label to the plot
prova.set(xlabel="Trial Index", ylabel="score")
if to_save_plots:
    prova.savefig(os.path.join(figures_path, 'Score_individual_trial_type.pdf'), format='pdf', dpi=300)
    prova.savefig(os.path.join(figures_path, 'Score_individual_trial_type.png'), format='png', dpi=300)

# %%
fig = sns.relplot(data=df_individual,
                  x="trialIdx",
                  y="score",
                  hue='plot_hue',
                  col="sessionId",
                  col_wrap=3,
                  kind="line",
                  errorbar='ci',
                  facet_kws=dict(sharey=True,sharex=False),
                  #palette={'individual, Human':'green', 'demonstration, Human':'#6bdb9c'},
                  height=7,
                  legend='full')
fig.set(xlabel="Trial number", ylabel="Score")
fig.fig.suptitle("Pilot 3B (Individual trials)")
if to_save_plots:
    fig.savefig(os.path.join(figures_path, 'Score_individual_trial_type_session.pdf'), format='pdf', dpi=300)
    fig.savefig(os.path.join(figures_path, 'Score_individual_trial_type_session.png'), format='png', dpi=300)

# %%
df_try_yourself
# Out:
#                     sessionId   isAI          expName  generation  trialIdx  \
# 70   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      10.0
# 71   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      12.0
# 72   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      13.0
# 73   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      15.0
# 74   6422d978aff8868105633832  Human  rn-iii-pilot-3B           1      17.0
# ..                        ...    ...              ...         ...       ...
# 217  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      15.0
# 218  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      17.0
# 219  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      19.0
# 220  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      20.0
# 221  6422d978aff886810563383c  Human  rn-iii-pilot-3B           1      22.0
#
#                trialType                         networkId   score  \
# 70   try_yourself_before  51edc36de506ff346ed262c1081554eb   800.0
# 71    try_yourself_after  51edc36de506ff346ed262c1081554eb  1150.0
# 72   try_yourself_before  31d35353bbfefdb5c7596273e9615d25   850.0
# 73    try_yourself_after  31d35353bbfefdb5c7596273e9615d25  1050.0
# 74   try_yourself_before  6432e2a0cd8bcd98e8be048855473b47   900.0
# ..                   ...                               ...     ...
# 217   try_yourself_after  ffac4c7b6e9a1d6afaa0d18b45bd17a4  1250.0
# 218  try_yourself_before  e3108a52b2badae980afc815b7277eb8  1450.0
# 219   try_yourself_after  e3108a52b2badae980afc815b7277eb8     0.0
# 220  try_yourself_before  dfae8f381c69dc91a7c5beea75e45a89   900.0
# 221   try_yourself_after  dfae8f381c69dc91a7c5beea75e45a89  1200.0
#
#      maxLevelReached  myopic_score  ai_score                    plot_hue
# 70               0.0         800.0    1450.0  Human, try_yourself_before
# 71               4.0         800.0    1450.0   Human, try_yourself_after
# 72               1.0        1000.0    1250.0  Human, try_yourself_before
# 73               1.0        1000.0    1250.0   Human, try_yourself_after
# 74               2.0         600.0     850.0  Human, try_yourself_before
# ..               ...           ...       ...                         ...
# 217              4.0         550.0    1250.0   Human, try_yourself_after
# 218              4.0           0.0    1450.0  Human, try_yourself_before
# 219              0.0           0.0    1450.0   Human, try_yourself_after
# 220              2.0        1200.0    1050.0  Human, try_yourself_before
# 221              0.0        1200.0    1050.0   Human, try_yourself_after
#
# [80 rows x 12 columns]

# %%
df_try_yourself.loc[df_try_yourself['trialIdx']==10,'trialIdx']=1
df_try_yourself.loc[df_try_yourself['trialIdx']==13,'trialIdx']=2
df_try_yourself.loc[df_try_yourself['trialIdx']==17,'trialIdx']=3
df_try_yourself.loc[df_try_yourself['trialIdx']==20,'trialIdx']=4
df_try_yourself.loc[df_try_yourself['trialIdx']==12,'trialIdx']=5
df_try_yourself.loc[df_try_yourself['trialIdx']==15,'trialIdx']=6
df_try_yourself.loc[df_try_yourself['trialIdx']==19,'trialIdx']=7
df_try_yourself.loc[df_try_yourself['trialIdx']==22,'trialIdx']=8


# individual performance over trial idx (score)
prova = sns.relplot(data=df_try_yourself, x="trialIdx", y="score",
                    hue='plot_hue', kind="line", errorbar='sd',
                    facet_kws=dict(sharey=True,sharex=False))
# add label to the axis and label to the plot
prova.set(xlabel="Trial Index", ylabel="score")
if to_save_plots:
    prova.savefig(os.path.join(figures_path, 'Score_try_yourself_trial_type.pdf'), format='pdf', dpi=300)
    prova.savefig(os.path.join(figures_path, 'Score_try_yourself_trial_type.png'), format='png', dpi=300)


fig = sns.relplot(data=df_try_yourself,
                  x="trialIdx",
                  y="score",
                  hue='plot_hue',
                  col="sessionId",
                  col_wrap=3,
                  kind="line",
                  errorbar='ci',
                  facet_kws=dict(sharey=True,sharex=False),
                  #palette={'individual, Human':'green', 'demonstration, Human':'#6bdb9c'},
                  height=7,
                  legend='full')
fig.set(xlabel="Trial number", ylabel="Score")
fig.fig.suptitle("Pilot 3B (Social learning try yourself trials)")
if to_save_plots:
    fig.savefig(os.path.join(figures_path, 'Score_try_yourself_trial_type_session.pdf'), format='pdf', dpi=300)
    fig.savefig(os.path.join(figures_path, 'Score_try_yourself_trial_type_session.png'), format='png', dpi=300)

# %% [markdown]
# ## Explore individual trials

# %%
scores_df = pd.read_csv(os.path.join(data_path,"scores.csv"),index_col=0)
moves = pd.read_csv(os.path.join(f"../../data/final/rn-iii-pilot-3B/moves.csv"),sep=',', index_col=0)

# %%
df = scores_df[scores_df['trialType'].isin(['individual', 'try_yourself', 'demonstration']) & scores_df['isAI'] == False].reset_index(drop=True)

# add columns move_1 to move_8
for i in range(1,9):
    df[f'move_{i}'] = np.nan

# add moves from the moves dataframe to df based on the session id and trial index
for i in range(1,9):
    for idx, row in df.iterrows():
        df.loc[idx, f'move_{i}'] = moves[
            (moves['sessionId'] == row['sessionId']) &
            (moves['trialID'] == row['trialIdx']) &
            (moves['step'] == i)
        ]['reward'].values[0]

df.head(10)

# add short session id with the last 3 characters
df['id'] = df['sessionId'].str[-3:]

# check that id is unique
assert len(df['id'].unique()) == len(df['sessionId'].unique())

# reorganize columns
df = df[['id', 'trialIdx', 'trialType', 'score', 'maxLevelReached', 'move_1', 'move_2', 'move_3', 'move_4', 'move_5', 'move_6', 'move_7', 'move_8', 'networkId', 'myopic_score', 'ai_score', 'sessionId']]

# sort by session id and trial index
df = df.sort_values(by=['sessionId', 'trialIdx']).reset_index(drop=True)

# %%
df.to_csv(f"../../data/final/rn-iii-pilot-3B/scores_&_moves.csv", index=False)
